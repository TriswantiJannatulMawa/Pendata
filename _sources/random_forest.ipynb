# %% [markdown]
# # Random Forest
#
# ## Analisis Random Forest menggunakan KNIME
#
# ![alt text](image9.png)
#
# ### 1. Exel Reader
#
# ### 2. Missing Value
#
# ### 3. Table Partitioner
#
# ### 4. Random Forest Lenear
#
# ### 5. Tree Ensemble Statistic
#
# ### 6. Random Forest Prediction
#
# ### 7. Scorer
